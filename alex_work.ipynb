# %%
import pandas as pd 

v1 = pd.read_csv("data/cost-of-living.csv", index_col=0)
v2 = pd.read_csv("data/cost-of-living_v2.csv")

# %%
# Exploring differences between dataset versions
outer = pd.merge(v1, v2, how='outer', indicator=True)
outer.groupby("_merge")['city'].count() #
# Out:
# _merge
# left_only     4030
# right_only    4112
# both           844
# Name: city, dtype: int64

# %%
# At least some of these differences are due to different values across the quantitative columns:
outer.sort_values("city").head(2)
# Out:
#                   city      country     x1     x2    x3    x4    x5    x6  \
# 6833  's-Hertogenbosch  Netherlands  18.97  63.22  9.11  4.35  3.16  3.06
# 2147  's-Hertogenbosch  Netherlands  18.70  62.32  8.98  4.28  3.12  3.02
#
#         x7    x8  ...     x48     x49      x50      x51     x52      x53  \
# 6833  2.83  2.29  ...  964.18  753.43  1830.88  1448.90  4531.1  3301.74
# 2147  2.79  2.26  ...  950.41  742.67  1804.74  1428.21  4466.4  3254.58
#
#           x54   x55  data_quality      _merge
# 6833  2669.49  2.27             1  right_only
# 2147  2631.36  2.27             1   left_only
#
# [2 rows x 59 columns]

# %%
# Some of these differences are from cities being included in one version but not the other
city_diff = pd.merge(v1.city, v2.city, how = "outer", indicator=True) 
city_diff = city_diff[city_diff._merge != "both"]

dropped_cities = list(city_diff[city_diff['_merge'] == "left_only"].city) # Cities present in v1 but not v2
v1_only = v1.loc[v1.city.isin(dropped_cities)]

# %%
cost_living = pd.merge(v1_only, v2, how = "outer")
cost_living
# Out:
#                     city        country     x1     x2     x3     x4    x5  \
# 0                Guigang          China   2.30  20.95   4.40    NaN  2.79
# 1            Sidi Bouzid        Tunisia   1.85  16.22   2.78   1.39  1.31
# 2                  Zaria        Nigeria   1.24   5.52   5.63   1.13  1.58
# 3               Paulista         Brazil   4.10  18.63   5.59   1.12  1.86
# 4                  Houma  United States  10.00    NaN  10.00    NaN   NaN
# ...                  ...            ...    ...    ...    ...    ...   ...
# 4965        Peterborough      Australia    NaN    NaN    NaN    NaN   NaN
# 4966          Georgetown      Australia    NaN    NaN    NaN    NaN   NaN
# 4967  Ixtapa Zihuatanejo         Mexico   5.16  30.94  12.89   0.98   NaN
# 4968             Iqaluit         Canada  29.65  74.27  13.71   6.67  8.89
# 4969              Neiafu          Tonga    NaN  29.79  10.64  10.64   NaN
#
#         x6    x7    x8  ...     x47     x48     x49      x50      x51  x52  \
# 0     2.10  0.49  0.30  ...  130.37     NaN     NaN      NaN      NaN  NaN
# 1     0.69  0.50  0.20  ...   59.74  154.49  154.49   370.77   370.77  NaN
# 2     2.14  0.23  0.25  ...   74.35  112.65  225.29   337.94   901.16  NaN
# 3     1.18  0.93  0.37  ...   40.90  108.08   93.17   195.65   121.12  NaN
# 4     5.00   NaN   NaN  ...   89.50  950.00     NaN      NaN      NaN  NaN
# ...    ...   ...   ...  ...     ...     ...     ...      ...      ...  ...
# 4965   NaN   NaN   NaN  ...     NaN     NaN     NaN      NaN      NaN  NaN
# 4966   NaN   NaN   NaN  ...     NaN     NaN     NaN      NaN      NaN  NaN
# 4967  1.80  0.62  0.41  ...  103.14  412.55  257.84   515.69   412.55  NaN
# 4968  3.71  3.52  4.08  ...     NaN     NaN     NaN  2964.60  2964.60  NaN
# 4969   NaN  2.13  2.13  ...     NaN     NaN     NaN      NaN      NaN  NaN
#
#       x53     x54    x55  data_quality
# 0     NaN     NaN   4.18             0
# 1     NaN  253.36   8.20             0
# 2     NaN  157.70  17.67             0
# 3     NaN  195.65   9.25             0
# 4     NaN     NaN    NaN             0
# ...   ...     ...    ...           ...
# 4965  NaN     NaN    NaN             0
# 4966  NaN     NaN    NaN             0
# 4967  NaN     NaN    NaN             0
# 4968  NaN     NaN   6.53             0
# 4969  NaN     NaN    NaN             0
#
# [4970 rows x 58 columns]
