# %%
import pandas as pd 

v1 = pd.read_csv("data/unclean/cost-of-living.csv", index_col=0)
v2 = pd.read_csv("data/unclean/cost-of-living_v2.csv")

# %%
# Exploring differences between dataset versions
outer = pd.merge(v1, v2, how='outer', indicator=True)
outer.groupby("_merge")['city'].count() #
# Out:
# _merge
# left_only     4030
# right_only    4112
# both           844
# Name: city, dtype: int64

# %%
# At least some of these differences are due to different values across the quantitative columns:
outer.sort_values("city").head(2)
# Out:
#                   city      country     x1     x2    x3    x4    x5    x6  \
# 6833  's-Hertogenbosch  Netherlands  18.97  63.22  9.11  4.35  3.16  3.06
# 2147  's-Hertogenbosch  Netherlands  18.70  62.32  8.98  4.28  3.12  3.02
#
#         x7    x8  ...     x48     x49      x50      x51     x52      x53  \
# 6833  2.83  2.29  ...  964.18  753.43  1830.88  1448.90  4531.1  3301.74
# 2147  2.79  2.26  ...  950.41  742.67  1804.74  1428.21  4466.4  3254.58
#
#           x54   x55  data_quality      _merge
# 6833  2669.49  2.27             1  right_only
# 2147  2631.36  2.27             1   left_only
#
# [2 rows x 59 columns]

# %%
# Some of these differences are from cities being included in one version but not the other
city_diff = pd.merge(v1.city, v2.city, how = "outer", indicator=True) 
city_diff = city_diff[city_diff._merge != "both"]

dropped_cities = list(city_diff[city_diff['_merge'] == "left_only"].city) # Cities present in v1 but not v2
v1_only = v1.loc[v1.city.isin(dropped_cities)]

# %%
cost_living = pd.merge(v1_only, v2, how = "outer")

# The below file is from text copy-pasted from kaggle page's description section:
      # https://www.kaggle.com/datasets/mvieira101/global-cost-of-livin
column_descriptions = pd.read_csv("data/column_descriptions.csv",sep="	") 
column_descriptions = column_descriptions.iloc[1:56,] # Drop descriptions of columns whose names we don't want to change
col_key = dict(zip(column_descriptions['city'],column_descriptions['Name of the city']))
cost_living.rename(col_key, axis=1, inplace = True)
cost_living.head(1)
# The original dummy columns were entirely uninformative, but now many of these are too long. Alas.
# Out:
#       city country  Meal, Inexpensive Restaurant (USD)  \
# 0  Guigang   China                                 2.3
#
#    Meal for 2 People, Mid-range Restaurant, Three-course (USD)  \
# 0                                              20.95
#
#    McMeal at McDonalds (or Equivalent Combo Meal) (USD)  \
# 0                                                4.4
#
#    Domestic Beer (0.5 liter draught, in restaurants) (USD)  \
# 0                                                NaN
#
#    Imported Beer (0.33 liter bottle, in restaurants) (USD)  \
# 0                                               2.79
#
#    Cappuccino (regular, in restaurants) (USD)  \
# 0                                         2.1
#
#    Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)  \
# 0                                               0.49
#
#    Water (0.33 liter bottle, in restaurants) (USD)  ...  \
# 0                                              0.3  ...
#
#    1 Pair of Men Leather Business Shoes (USD)  \
# 0                                      130.37
#
#    Apartment (1 bedroom) in City Centre (USD)  \
# 0                                         NaN
#
#    Apartment (1 bedroom) Outside of Centre (USD)  \
# 0                                            NaN
#
#    Apartment (3 bedrooms) in City Centre (USD)  \
# 0                                          NaN
#
#    Apartment (3 bedrooms) Outside of Centre (USD)  \
# 0                                             NaN
#
#    Price per Square Meter to Buy Apartment in City Centre (USD)  \
# 0                                                NaN
#
#    Price per Square Meter to Buy Apartment Outside of Centre (USD)  \
# 0                                                NaN
#
#    Average Monthly Net Salary (After Tax) (USD)  \
# 0                                           NaN
#
#    Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate  \
# 0                                               4.18
#
#    data_quality
# 0             0
#
# [1 rows x 58 columns]

# %% [markdown]
# #### Cleaning the Data Set

# %%
cost_living.drop_duplicates() # No duplicates...beautiful
# Out:
#                     city        country  Meal, Inexpensive Restaurant (USD)  \
# 0                Guigang          China                                2.30
# 1            Sidi Bouzid        Tunisia                                1.85
# 2                  Zaria        Nigeria                                1.24
# 3               Paulista         Brazil                                4.10
# 4                  Houma  United States                               10.00
# ...                  ...            ...                                 ...
# 4965        Peterborough      Australia                                 NaN
# 4966          Georgetown      Australia                                 NaN
# 4967  Ixtapa Zihuatanejo         Mexico                                5.16
# 4968             Iqaluit         Canada                               29.65
# 4969              Neiafu          Tonga                                 NaN
#
#       Meal for 2 People, Mid-range Restaurant, Three-course (USD)  \
# 0                                                 20.95
# 1                                                 16.22
# 2                                                  5.52
# 3                                                 18.63
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                              30.94
# 4968                                              74.27
# 4969                                              29.79
#
#       McMeal at McDonalds (or Equivalent Combo Meal) (USD)  \
# 0                                                  4.40
# 1                                                  2.78
# 2                                                  5.63
# 3                                                  5.59
# 4                                                 10.00
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                              12.89
# 4968                                              13.71
# 4969                                              10.64
#
#       Domestic Beer (0.5 liter draught, in restaurants) (USD)  \
# 0                                                   NaN
# 1                                                  1.39
# 2                                                  1.13
# 3                                                  1.12
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                               0.98
# 4968                                               6.67
# 4969                                              10.64
#
#       Imported Beer (0.33 liter bottle, in restaurants) (USD)  \
# 0                                                  2.79
# 1                                                  1.31
# 2                                                  1.58
# 3                                                  1.86
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                                NaN
# 4968                                               8.89
# 4969                                                NaN
#
#       Cappuccino (regular, in restaurants) (USD)  \
# 0                                           2.10
# 1                                           0.69
# 2                                           2.14
# 3                                           1.18
# 4                                           5.00
# ...                                          ...
# 4965                                         NaN
# 4966                                         NaN
# 4967                                        1.80
# 4968                                        3.71
# 4969                                         NaN
#
#       Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)  \
# 0                                                  0.49
# 1                                                  0.50
# 2                                                  0.23
# 3                                                  0.93
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                               0.62
# 4968                                               3.52
# 4969                                               2.13
#
#       Water (0.33 liter bottle, in restaurants) (USD)  ...  \
# 0                                                0.30  ...
# 1                                                0.20  ...
# 2                                                0.25  ...
# 3                                                0.37  ...
# 4                                                 NaN  ...
# ...                                               ...  ...
# 4965                                              NaN  ...
# 4966                                              NaN  ...
# 4967                                             0.41  ...
# 4968                                             4.08  ...
# 4969                                             2.13  ...
#
#       1 Pair of Men Leather Business Shoes (USD)  \
# 0                                         130.37
# 1                                          59.74
# 2                                          74.35
# 3                                          40.90
# 4                                          89.50
# ...                                          ...
# 4965                                         NaN
# 4966                                         NaN
# 4967                                      103.14
# 4968                                         NaN
# 4969                                         NaN
#
#       Apartment (1 bedroom) in City Centre (USD)  \
# 0                                            NaN
# 1                                         154.49
# 2                                         112.65
# 3                                         108.08
# 4                                         950.00
# ...                                          ...
# 4965                                         NaN
# 4966                                         NaN
# 4967                                      412.55
# 4968                                         NaN
# 4969                                         NaN
#
#       Apartment (1 bedroom) Outside of Centre (USD)  \
# 0                                               NaN
# 1                                            154.49
# 2                                            225.29
# 3                                             93.17
# 4                                               NaN
# ...                                             ...
# 4965                                            NaN
# 4966                                            NaN
# 4967                                         257.84
# 4968                                            NaN
# 4969                                            NaN
#
#       Apartment (3 bedrooms) in City Centre (USD)  \
# 0                                             NaN
# 1                                          370.77
# 2                                          337.94
# 3                                          195.65
# 4                                             NaN
# ...                                           ...
# 4965                                          NaN
# 4966                                          NaN
# 4967                                       515.69
# 4968                                      2964.60
# 4969                                          NaN
#
#       Apartment (3 bedrooms) Outside of Centre (USD)  \
# 0                                                NaN
# 1                                             370.77
# 2                                             901.16
# 3                                             121.12
# 4                                                NaN
# ...                                              ...
# 4965                                             NaN
# 4966                                             NaN
# 4967                                          412.55
# 4968                                         2964.60
# 4969                                             NaN
#
#       Price per Square Meter to Buy Apartment in City Centre (USD)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                                NaN
# 4968                                                NaN
# 4969                                                NaN
#
#       Price per Square Meter to Buy Apartment Outside of Centre (USD)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                                NaN
# 4968                                                NaN
# 4969                                                NaN
#
#       Average Monthly Net Salary (After Tax) (USD)  \
# 0                                              NaN
# 1                                           253.36
# 2                                           157.70
# 3                                           195.65
# 4                                              NaN
# ...                                            ...
# 4965                                           NaN
# 4966                                           NaN
# 4967                                           NaN
# 4968                                           NaN
# 4969                                           NaN
#
#       Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate  \
# 0                                                  4.18
# 1                                                  8.20
# 2                                                 17.67
# 3                                                  9.25
# 4                                                   NaN
# ...                                                 ...
# 4965                                                NaN
# 4966                                                NaN
# 4967                                                NaN
# 4968                                               6.53
# 4969                                                NaN
#
#       data_quality
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 4965             0
# 4966             0
# 4967             0
# 4968             0
# 4969             0
#
# [4970 rows x 58 columns]

# %%
cost_living.apply(lambda col: col.isna().sum(), axis=0).sort_values(ascending=False)
# Out:
# Tennis Court Rent (1 Hour on Weekend) (USD)                                       2410
# Price per Square Meter to Buy Apartment Outside of Centre (USD)                   2315
# Price per Square Meter to Buy Apartment in City Centre (USD)                      2237
# Monthly Pass (Regular Price) (USD)                                                2177
# International Primary School, Yearly for 1 Child (USD)                            1687
# Apartment (3 bedrooms) Outside of Centre (USD)                                    1519
# One-way Ticket (Local Transport) (USD)                                            1514
# Apartment (3 bedrooms) in City Centre (USD)                                       1488
# Average Monthly Net Salary (After Tax) (USD)                                      1439
# Apartment (1 bedroom) Outside of Centre (USD)                                     1436
# Taxi 1hour Waiting (Normal Tariff) (USD)                                          1401
# Fitness Club, Monthly Fee for 1 Adult (USD)                                       1383
# Apartment (1 bedroom) in City Centre (USD)                                        1369
# 1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans) (USD)               1207
# Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)         1138
# Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car) (USD)                 1063
# Taxi 1km (Normal Tariff) (USD)                                                    1026
# Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate        1013
# Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car) (USD)              1001
# Taxi Start (Normal Tariff) (USD)                                                   878
# Domestic Beer (0.5 liter bottle, at the market) (USD)                              728
# Imported Beer (0.33 liter bottle, at the market) (USD)                             660
# 1 Summer Dress in a Chain Store (Zara, H&M, …) (USD)                               622
# Gasoline (1 liter) (USD)                                                           592
# Beef Round (1kg) (or Equivalent Back Leg Red Meat) (USD)                           572
# Chicken Fillets (1kg) (USD)                                                        565
# 1 Pair of Men Leather Business Shoes (USD)                                         554
# Eggs (regular) (12) (USD)                                                          512
# 1 Pair of Nike Running Shoes (Mid-Range) (USD)                                     505
# Lettuce (1 head) (USD)                                                             505
# Domestic Beer (0.5 liter draught, in restaurants) (USD)                            502
# Cigarettes 20 Pack (Marlboro) (USD)                                                496
# Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment (USD)     489
# Local Cheese (1kg) (USD)                                                           484
# 1 Pair of Jeans (Levis 501 Or Similar) (USD)                                       482
# Cinema, International Release, 1 Seat (USD)                                        477
# Tomato (1kg) (USD)                                                                 474
# Bottle of Wine (Mid-Range, at the market) (USD)                                    468
# Meal for 2 People, Mid-range Restaurant, Three-course (USD)                        456
# Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)                               449
# Oranges (1kg) (USD)                                                                446
# Imported Beer (0.33 liter bottle, in restaurants) (USD)                            444
# Potato (1kg) (USD)                                                                 443
# Onion (1kg) (USD)                                                                  438
# Meal, Inexpensive Restaurant (USD)                                                 432
# Loaf of Fresh White Bread (500g) (USD)                                             419
# Water (1.5 liter bottle, at the market) (USD)                                      393
# Banana (1kg) (USD)                                                                 385
# Milk (regular), (1 liter) (USD)                                                    382
# Apples (1kg) (USD)                                                                 377
# Internet (60 Mbps or More, Unlimited Data, Cable/ADSL) (USD)                       350
# Cappuccino (regular, in restaurants) (USD)                                         347
# Rice (white), (1kg) (USD)                                                          346
# McMeal at McDonalds (or Equivalent Combo Meal) (USD)                               335
# Water (0.33 liter bottle, in restaurants) (USD)                                    319
# city                                                                                 0
# country                                                                              0
# data_quality                                                                         0
# dtype: int64

# %%
apartments1 = cost_living.dropna(subset=['Price per Square Meter to Buy Apartment in City Centre (USD)','Price per Square Meter to Buy Apartment Outside of Centre (USD)'], axis=0) # rows that have price/sqmeter data
apartments2 = cost_living.dropna(subset=cost_living.columns[49:53], axis=0) # rows that have data for apartment rent by location and bedrooms
apartments3 = cost_living.dropna(subset=cost_living.columns[49:55], axis=0) # rows that have data in all apartment-related columns

# all_apartment_columns = list(cost_living.columns[cost_living.columns.str.contains("[aA]partment")]) --- all the apartment-related columns, including price/sqmeter.
### replaced with slicing above for visual clarity

# %%
apartments3
# Out:
#                      city      country  Meal, Inexpensive Restaurant (USD)  \
# 10    Smederevska Palanka       Serbia                                 NaN
# 13             Szentendre      Hungary                                5.94
# 14                  Seoul  South Korea                                7.68
# 15               Shanghai        China                                5.69
# 16              Guangzhou        China                                4.13
# ...                   ...          ...                                 ...
# 4952           Seferhisar       Turkey                                3.22
# 4955               Mackay    Australia                               16.31
# 4959             Tirupati        India                                2.46
# 4961          Rockhampton    Australia                               14.95
# 4964         Egilsstadhir      Iceland                               17.01
#
#       Meal for 2 People, Mid-range Restaurant, Three-course (USD)  \
# 10                                                  NaN
# 13                                                25.57
# 14                                                53.78
# 15                                                39.86
# 16                                                28.47
# ...                                                 ...
# 4952                                              18.78
# 4955                                              81.55
# 4959                                               9.21
# 4961                                              64.56
# 4964                                              70.87
#
#       McMeal at McDonalds (or Equivalent Combo Meal) (USD)  \
# 10                                                 3.54
# 13                                                 4.32
# 14                                                 6.15
# 15                                                 5.69
# 16                                                 4.98
# ...                                                 ...
# 4952                                               1.61
# 4955                                               8.83
# 4959                                               4.30
# 4961                                               8.15
# 4964                                               8.50
#
#       Domestic Beer (0.5 liter draught, in restaurants) (USD)  \
# 10                                                  NaN
# 13                                                 1.65
# 14                                                 3.07
# 15                                                 1.14
# 16                                                 0.85
# ...                                                 ...
# 4952                                               2.15
# 4955                                               4.59
# 4959                                               2.21
# 4961                                               4.25
# 4964                                               4.25
#
#       Imported Beer (0.33 liter bottle, in restaurants) (USD)  \
# 10                                                  NaN
# 13                                                 1.48
# 14                                                 4.99
# 15                                                 4.27
# 16                                                 1.71
# ...                                                 ...
# 4952                                               2.15
# 4955                                               5.44
# 4959                                               3.07
# 4961                                               3.40
# 4964                                               3.54
#
#       Cappuccino (regular, in restaurants) (USD)  \
# 10                                           NaN
# 13                                          1.45
# 14                                          3.93
# 15                                          3.98
# 16                                          3.54
# ...                                          ...
# 4952                                        2.33
# 4955                                        4.87
# 4959                                        1.47
# 4961                                        3.40
# 4964                                        3.90
#
#       Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)  \
# 10                                                 1.06
# 13                                                 1.05
# 14                                                 1.48
# 15                                                 0.53
# 16                                                 0.44
# ...                                                 ...
# 4952                                               0.54
# 4955                                               2.49
# 4959                                               0.46
# 4961                                               2.74
# 4964                                               1.77
#
#       Water (0.33 liter bottle, in restaurants) (USD)  ...  \
# 10                                               0.88  ...
# 13                                               0.86  ...
# 14                                               0.79  ...
# 15                                               0.33  ...
# 16                                               0.33  ...
# ...                                               ...  ...
# 4952                                             0.21  ...
# 4955                                             2.38  ...
# 4959                                             0.14  ...
# 4961                                             2.38  ...
# 4964                                             1.42  ...
#
#       1 Pair of Men Leather Business Shoes (USD)  \
# 10                                         35.40
# 13                                         85.23
# 14                                        110.36
# 15                                        123.51
# 16                                         43.89
# ...                                          ...
# 4952                                       67.08
# 4955                                       84.27
# 4959                                       37.25
# 4961                                       54.37
# 4964                                      146.00
#
#       Apartment (1 bedroom) in City Centre (USD)  \
# 10                                        106.19
# 13                                        485.82
# 14                                        742.54
# 15                                       1091.93
# 16                                        533.28
# ...                                          ...
# 4952                                      321.99
# 4955                                      736.21
# 4959                                       82.90
# 4961                                      781.58
# 4964                                      637.85
#
#       Apartment (1 bedroom) Outside of Centre (USD)  \
# 10                                            88.49
# 13                                           375.02
# 14                                           557.52
# 15                                           569.88
# 16                                           317.45
# ...                                             ...
# 4952                                         268.33
# 4955                                         679.58
# 4959                                          61.41
# 4961                                         594.63
# 4964                                         531.54
#
#       Apartment (3 bedrooms) in City Centre (USD)  \
# 10                                         132.73
# 13                                         852.32
# 14                                        2669.12
# 15                                        2952.70
# 16                                        1242.24
# ...                                           ...
# 4952                                       429.33
# 4955                                      1359.16
# 4959                                       184.23
# 4961                                       951.41
# 4964                                      1700.92
#
#       Apartment (3 bedrooms) Outside of Centre (USD)  \
# 10                                            106.19
# 13                                            639.24
# 14                                           1731.08
# 15                                           1561.59
# 16                                            688.05
# ...                                              ...
# 4952                                          321.99
# 4955                                         1087.33
# 4959                                          128.96
# 4961                                          906.11
# 4964                                         1417.43
#
#       Price per Square Meter to Buy Apartment in City Centre (USD)  \
# 10                                               309.71
# 13                                              2556.95
# 14                                             22067.70
# 15                                             17746.11
# 16                                             12892.82
# ...                                                 ...
# 4952                                            1287.98
# 4955                                           11213.06
# 4959                                             661.00
# 4961                                            5097.49
# 4964                                            2019.84
#
#       Price per Square Meter to Buy Apartment Outside of Centre (USD)  \
# 10                                               265.47
# 13                                              2173.41
# 14                                             10971.90
# 15                                              9416.35
# 16                                              5427.45
# ...                                                 ...
# 4952                                             536.66
# 4955                                           10091.76
# 4959                                             396.60
# 4961                                            4019.31
# 4964                                            1771.79
#
#       Average Monthly Net Salary (After Tax) (USD)  \
# 10                                             NaN
# 13                                          895.12
# 14                                         2689.62
# 15                                         1419.87
# 16                                         1211.68
# ...                                            ...
# 4952                                           NaN
# 4955                                       3737.69
# 4959                                        614.09
# 4961                                       3481.06
# 4964                                       2480.51
#
#       Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate  \
# 10                                                  NaN
# 13                                                 7.42
# 14                                                 3.47
# 15                                                 5.03
# 16                                                 5.19
# ...                                                 ...
# 4952                                                NaN
# 4955                                               5.80
# 4959                                               7.97
# 4961                                               5.80
# 4964                                               5.00
#
#       data_quality
# 10               0
# 13               0
# 14               1
# 15               1
# 16               1
# ...            ...
# 4952             0
# 4955             0
# 4959             0
# 4961             0
# 4964             0
#
# [2292 rows x 58 columns]

# %%
price_sq_meter = apartments1[['city','country','Price per Square Meter to Buy Apartment in City Centre (USD)', 'data_quality']]

# %%
price_sq_meter
# Out:
#                      city      country  \
# 10    Smederevska Palanka       Serbia
# 13             Szentendre      Hungary
# 14                  Seoul  South Korea
# 15               Shanghai        China
# 16              Guangzhou        China
# ...                   ...          ...
# 4952           Seferhisar       Turkey
# 4955               Mackay    Australia
# 4959             Tirupati        India
# 4961          Rockhampton    Australia
# 4964         Egilsstadhir      Iceland
#
#       Price per Square Meter to Buy Apartment in City Centre (USD)  \
# 10                                               309.71
# 13                                              2556.95
# 14                                             22067.70
# 15                                             17746.11
# 16                                             12892.82
# ...                                                 ...
# 4952                                            1287.98
# 4955                                           11213.06
# 4959                                             661.00
# 4961                                            5097.49
# 4964                                            2019.84
#
#       data_quality
# 10               0
# 13               0
# 14               1
# 15               1
# 16               1
# ...            ...
# 4952             0
# 4955             0
# 4959             0
# 4961             0
# 4964             0
#
# [2537 rows x 4 columns]

# %%
worldcities = pd.read_csv("data/worldcities.csv").drop_duplicates(["city", "country"])
worldcities
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3           Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4        São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# ...            ...          ...      ...       ...          ...  ...  ...
# 42900       Tukchi       Tukchi  57.3670  139.5000       Russia   RU  RUS
# 42901        Numto        Numto  63.6667   71.3333       Russia   RU  RUS
# 42902         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 42903  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 42904      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                                      admin_name  capital  population  \
# 0                                         Tōkyō  primary  39105000.0
# 1                                       Jakarta  primary  35362000.0
# 2                                         Delhi    admin  31870000.0
# 3                                        Manila  primary  23971000.0
# 4                                     São Paulo    admin  22495000.0
# ...                                         ...      ...         ...
# 42900                         Khabarovskiy Kray      NaN        10.0
# 42901  Khanty-Mansiyskiy Avtonomnyy Okrug-Yugra      NaN        10.0
# 42902                                Sermersooq      NaN        10.0
# 42903                                  Kujalleq      NaN        10.0
# 42904                        Krasnoyarskiy Kray      NaN         0.0
#
#                id
# 0      1392685764
# 1      1360771077
# 2      1356872604
# 3      1608618140
# 4      1076532519
# ...           ...
# 42900  1643472801
# 42901  1643985006
# 42902  1304217709
# 42903  1304206491
# 42904  1643587468
#
# [40401 rows x 11 columns]

# %%
combo = pd.read_csv("data/cl_real_happiness.csv")
combo.rename(columns=lambda v: v + " (country)", inplace=True)
combo.rename(mapper={"city (country)":"city", "country (country)":"country", "price_per_sq_meter (country)":"price_per_sq_meter"}, inplace=True, axis=1)
combo.drop("Country name (country)", axis=1, inplace=True)
combo
# Out:
#               city        country  price_per_sq_meter  Ladder score (country)  \
# 0       Carrollton  United States             9848.98                    6.94
# 1      Dania Beach  United States             1776.05                    6.94
# 2         New York  United States            14784.44                    6.94
# 3      Los Angeles  United States             9219.44                    6.94
# 4          Chicago  United States             3498.00                    6.94
# ...            ...            ...                 ...                     ...
# 4959  Petion-Ville          Haiti             2960.08                    3.72
# 4960      Curepipe      Mauritius              412.37                    6.10
# 4961   Santa Tecla    El Salvador             1068.00                    6.35
# 4962      Alajuela     Costa Rica             1219.89                    7.12
# 4963       Heredia     Costa Rica             1452.51                    7.12
#
#       Logged GDP per capita (country)  Social support (country)  \
# 0                               10.93                      0.91
# 1                               10.93                      0.91
# 2                               10.93                      0.91
# 3                               10.93                      0.91
# 4                               10.93                      0.91
# ...                               ...                       ...
# 4959                             7.41                      0.59
# 4960                             9.96                      0.91
# 4961                             8.91                      0.81
# 4962                             9.66                      0.90
# 4963                             9.66                      0.90
#
#       Healthy life expectancy (country)  \
# 0                                 68.30
# 1                                 68.30
# 2                                 68.30
# 3                                 68.30
# 4                                 68.30
# ...                                 ...
# 4959                              55.60
# 4960                              66.40
# 4961                              66.11
# 4962                              71.30
# 4963                              71.30
#
#       Freedom to make life choices (country)  Generosity (country)  \
# 0                                       0.84                  0.15
# 1                                       0.84                  0.15
# 2                                       0.84                  0.15
# 3                                       0.84                  0.15
# 4                                       0.84                  0.15
# ...                                      ...                   ...
# 4959                                    0.54                  0.40
# 4960                                    0.89                 -0.02
# 4961                                    0.83                 -0.12
# 4962                                    0.93                 -0.10
# 4963                                    0.93                 -0.10
#
#       Perceptions of corruption (country)
# 0                                    0.70
# 1                                    0.70
# 2                                    0.70
# 3                                    0.70
# 4                                    0.70
# ...                                   ...
# 4959                                 0.68
# 4960                                 0.81
# 4961                                 0.75
# 4962                                 0.79
# 4963                                 0.79
#
# [4964 rows x 10 columns]

# %%
combo_locations = pd.merge(combo, worldcities, how="inner", on=['city', 'country'])
# Out:
#              city        country  price_per_sq_meter  Ladder score (country)  \
# 0      Carrollton  United States         9848.980000                    6.94
# 1     Dania Beach  United States         1776.050000                    6.94
# 2        New York  United States        14784.440000                    6.94
# 3        New York  United States        18919.719454                    6.94
# 4     Los Angeles  United States         9219.440000                    6.94
# ...           ...            ...                 ...                     ...
# 3151   Marsaxlokk          Malta         8611.130000                    6.77
# 3152     Curepipe      Mauritius          412.370000                    6.10
# 3153  Santa Tecla    El Salvador         1068.000000                    6.35
# 3154     Alajuela     Costa Rica         1219.890000                    7.12
# 3155      Heredia     Costa Rica         1452.510000                    7.12
#
#       Logged GDP per capita (country)  Social support (country)  \
# 0                               10.93                      0.91
# 1                               10.93                      0.91
# 2                               10.93                      0.91
# 3                               10.93                      0.91
# 4                               10.93                      0.91
# ...                               ...                       ...
# 3151                            10.53                      0.93
# 3152                             9.96                      0.91
# 3153                             8.91                      0.81
# 3154                             9.66                      0.90
# 3155                             9.66                      0.90
#
#       Healthy life expectancy (country)  \
# 0                                 68.30
# 1                                 68.30
# 2                                 68.30
# 3                                 68.30
# 4                                 68.30
# ...                                 ...
# 3151                              72.20
# 3152                              66.40
# 3153                              66.11
# 3154                              71.30
# 3155                              71.30
#
#       Freedom to make life choices (country)  Generosity (country)  \
# 0                                       0.84                  0.15
# 1                                       0.84                  0.15
# 2                                       0.84                  0.15
# 3                                       0.84                  0.15
# 4                                       0.84                  0.15
# ...                                      ...                   ...
# 3151                                    0.92                  0.21
# 3152                                    0.89                 -0.02
# 3153                                    0.83                 -0.12
# 3154                                    0.93                 -0.10
# 3155                                    0.93                 -0.10
#
#       Perceptions of corruption (country)   city_ascii      lat       lng  \
# 0                                    0.70   Carrollton  32.9890  -96.8999
# 1                                    0.70  Dania Beach  26.0594  -80.1637
# 2                                    0.70     New York  40.6943  -73.9249
# 3                                    0.70     New York  40.6943  -73.9249
# 4                                    0.70  Los Angeles  34.1139 -118.4068
# ...                                   ...          ...      ...       ...
# 3151                                 0.66   Marsaxlokk  35.8417   14.5447
# 3152                                 0.81     Curepipe -20.3162   57.5166
# 3153                                 0.75  Santa Tecla  13.6742  -89.2899
# 3154                                 0.79     Alajuela  10.0311  -84.2041
# 3155                                 0.79      Heredia   9.9985  -84.1169
#
#      iso2 iso3       admin_name capital  population          id
# 0      US  USA            Texas     NaN    139248.0  1840019436
# 1      US  USA          Florida     NaN     32271.0  1840015135
# 2      US  USA         New York     NaN  18713220.0  1840034016
# 3      US  USA         New York     NaN  18713220.0  1840034016
# 4      US  USA       California     NaN  12750807.0  1840020491
# ...   ...  ...              ...     ...         ...         ...
# 3151   MT  MLT       Marsaxlokk   admin      3534.0  1470596833
# 3152   MU  MUS  Plaines Wilhems     NaN    299975.0  1480343099
# 3153   SV  SLV      La Libertad   admin    135483.0  1222613306
# 3154   CR  CRI         Alajuela   admin     48326.0  1188394508
# 3155   CR  CRI          Heredia   admin     18988.0  1188210837
#
# [3156 rows x 19 columns]

# %%
import folium
m = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

for i in range(0, len(combo_locations)):
  folium.Marker(
    location=[combo_locations.iloc[i]['lat'],combo_locations.iloc[i]['lng']],
    popup=combo_locations.iloc[i]['city']
  ).add_to(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_acf4de1dad47a2668aab4557be1e486e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_acf4de1dad47a2668aab4557be1e486e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_acf4de1dad47a2668aab4557be1e486e = L.map(
#                 &quot;map_acf4de1dad47a2668aab4557be1e486e&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2d97a8910a4ee22a1cb4db2b7092e46 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_acf4de1dad47a2668aab4557be1e486e);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Choropleth(
  geo_data=combo_locations, 
  name="choropleth", 
  
)
# Out:
#              city        country  price_per_sq_meter  Ladder score (country)  \
# 0      Carrollton  United States         9848.980000                    6.94
# 1     Dania Beach  United States         1776.050000                    6.94
# 2        New York  United States        14784.440000                    6.94
# 3        New York  United States        18919.719454                    6.94
# 4     Los Angeles  United States         9219.440000                    6.94
# ...           ...            ...                 ...                     ...
# 3151   Marsaxlokk          Malta         8611.130000                    6.77
# 3152     Curepipe      Mauritius          412.370000                    6.10
# 3153  Santa Tecla    El Salvador         1068.000000                    6.35
# 3154     Alajuela     Costa Rica         1219.890000                    7.12
# 3155      Heredia     Costa Rica         1452.510000                    7.12
#
#       Logged GDP per capita (country)  Social support (country)  \
# 0                               10.93                      0.91
# 1                               10.93                      0.91
# 2                               10.93                      0.91
# 3                               10.93                      0.91
# 4                               10.93                      0.91
# ...                               ...                       ...
# 3151                            10.53                      0.93
# 3152                             9.96                      0.91
# 3153                             8.91                      0.81
# 3154                             9.66                      0.90
# 3155                             9.66                      0.90
#
#       Healthy life expectancy (country)  \
# 0                                 68.30
# 1                                 68.30
# 2                                 68.30
# 3                                 68.30
# 4                                 68.30
# ...                                 ...
# 3151                              72.20
# 3152                              66.40
# 3153                              66.11
# 3154                              71.30
# 3155                              71.30
#
#       Freedom to make life choices (country)  Generosity (country)  \
# 0                                       0.84                  0.15
# 1                                       0.84                  0.15
# 2                                       0.84                  0.15
# 3                                       0.84                  0.15
# 4                                       0.84                  0.15
# ...                                      ...                   ...
# 3151                                    0.92                  0.21
# 3152                                    0.89                 -0.02
# 3153                                    0.83                 -0.12
# 3154                                    0.93                 -0.10
# 3155                                    0.93                 -0.10
#
#       Perceptions of corruption (country)   city_ascii      lat       lng  \
# 0                                    0.70   Carrollton  32.9890  -96.8999
# 1                                    0.70  Dania Beach  26.0594  -80.1637
# 2                                    0.70     New York  40.6943  -73.9249
# 3                                    0.70     New York  40.6943  -73.9249
# 4                                    0.70  Los Angeles  34.1139 -118.4068
# ...                                   ...          ...      ...       ...
# 3151                                 0.66   Marsaxlokk  35.8417   14.5447
# 3152                                 0.81     Curepipe -20.3162   57.5166
# 3153                                 0.75  Santa Tecla  13.6742  -89.2899
# 3154                                 0.79     Alajuela  10.0311  -84.2041
# 3155                                 0.79      Heredia   9.9985  -84.1169
#
#      iso2 iso3       admin_name capital  population          id
# 0      US  USA            Texas     NaN    139248.0  1840019436
# 1      US  USA          Florida     NaN     32271.0  1840015135
# 2      US  USA         New York     NaN  18713220.0  1840034016
# 3      US  USA         New York     NaN  18713220.0  1840034016
# 4      US  USA       California     NaN  12750807.0  1840020491
# ...   ...  ...              ...     ...         ...         ...
# 3151   MT  MLT       Marsaxlokk   admin      3534.0  1470596833
# 3152   MU  MUS  Plaines Wilhems     NaN    299975.0  1480343099
# 3153   SV  SLV      La Libertad   admin    135483.0  1222613306
# 3154   CR  CRI         Alajuela   admin     48326.0  1188394508
# 3155   CR  CRI          Heredia   admin     18988.0  1188210837
#
# [3156 rows x 19 columns]

# %%
import pandas as pd

url = (
    "https://raw.githubusercontent.com/python-visualization/folium/master/examples/data"
)
state_geo = f"{url}/us-states.json"
# state_unemployment = f"{url}/US_Unemployment_Oct2012.csv"
# state_data = pd.read_csv(state_unemployment)
combo_locations


m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name="choropleth",
    data= ,# state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)",
).add_to(m)

folium.LayerControl().add_to(m)

state_data
# Out:
#    State  Unemployment
# 0     AL           7.1
# 1     AK           6.8
# 2     AZ           8.1
# 3     AR           7.2
# 4     CA          10.1
# 5     CO           7.7
# 6     CT           8.4
# 7     DE           7.1
# 8     FL           8.2
# 9     GA           8.8
# 10    HI           5.4
# 11    ID           6.6
# 12    IL           8.8
# 13    IN           8.4
# 14    IA           5.1
# 15    KS           5.6
# 16    KY           8.1
# 17    LA           5.9
# 18    ME           7.2
# 19    MD           6.8
# 20    MA           6.7
# 21    MI           9.1
# 22    MN           5.6
# 23    MS           9.1
# 24    MO           6.7
# 25    MT           5.8
# 26    NE           3.9
# 27    NV          10.3
# 28    NH           5.7
# 29    NJ           9.6
# 30    NM           6.8
# 31    NY           8.4
# 32    NC           9.4
# 33    ND           3.2
# 34    OH           6.9
# 35    OK           5.2
# 36    OR           8.5
# 37    PA           8.0
# 38    RI          10.1
# 39    SC           8.8
# 40    SD           4.4
# 41    TN           7.8
# 42    TX           6.4
# 43    UT           5.5
# 44    VT           5.0
# 45    VA           5.8
# 46    WA           7.8
# 47    WV           7.5
# 48    WI           6.8
# 49    WY           5.1

# %%
worldcities
# Out:
#               city   city_ascii      lat       lng      country iso2 iso3  \
# 0            Tokyo        Tokyo  35.6839  139.7744        Japan   JP  JPN
# 1          Jakarta      Jakarta  -6.2146  106.8451    Indonesia   ID  IDN
# 2            Delhi        Delhi  28.6667   77.2167        India   IN  IND
# 3           Manila       Manila  14.6000  120.9833  Philippines   PH  PHL
# 4        São Paulo    Sao Paulo -23.5504  -46.6339       Brazil   BR  BRA
# ...            ...          ...      ...       ...          ...  ...  ...
# 42900       Tukchi       Tukchi  57.3670  139.5000       Russia   RU  RUS
# 42901        Numto        Numto  63.6667   71.3333       Russia   RU  RUS
# 42902         Nord         Nord  81.7166  -17.8000    Greenland   GL  GRL
# 42903  Timmiarmiut  Timmiarmiut  62.5333  -42.2167    Greenland   GL  GRL
# 42904      Nordvik      Nordvik  74.0165  111.5100       Russia   RU  RUS
#
#                                      admin_name  capital  population  \
# 0                                         Tōkyō  primary  39105000.0
# 1                                       Jakarta  primary  35362000.0
# 2                                         Delhi    admin  31870000.0
# 3                                        Manila  primary  23971000.0
# 4                                     São Paulo    admin  22495000.0
# ...                                         ...      ...         ...
# 42900                         Khabarovskiy Kray      NaN        10.0
# 42901  Khanty-Mansiyskiy Avtonomnyy Okrug-Yugra      NaN        10.0
# 42902                                Sermersooq      NaN        10.0
# 42903                                  Kujalleq      NaN        10.0
# 42904                        Krasnoyarskiy Kray      NaN         0.0
#
#                id
# 0      1392685764
# 1      1360771077
# 2      1356872604
# 3      1608618140
# 4      1076532519
# ...           ...
# 42900  1643472801
# 42901  1643985006
# 42902  1304217709
# 42903  1304206491
# 42904  1643587468
#
# [40401 rows x 11 columns]
